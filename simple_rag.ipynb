# %%
import os
from dotenv import load_dotenv

# Get the current file's directory (all_rag_techniques)
current_dir = os.path.dirname(os.path.abspath('__file__'))

# Get the parent directory (RAG_Techniques)
parent_dir = os.path.dirname(current_dir)

# Construct the path to the .env file in the parent directory
dotenv_path = os.path.join(parent_dir, '.env')

# Load the .env file
load_dotenv(dotenv_path)

# Now you can use os.getenv to get your environment variables
api_key = os.getenv('OPENAI_API_KEY')

if api_key:
    print(f"API key loaded successfully. First 5 characters: {api_key[:5]}")
else:
    print("Failed to load API key from environment.")

print(f"Current working directory: {os.getcwd()}")
print(f"Parent directory (where .env should be): {parent_dir}")
print(f".env file path: {dotenv_path}")
print(f".env file exists: {os.path.exists(dotenv_path)}")

# If the .env file exists, print its contents (excluding the actual API key)
if os.path.exists(dotenv_path):
    with open(dotenv_path, 'r') as file:
        contents = file.read()
        print("\nContents of .env file (API key redacted):")
        for line in contents.split('\n'):
            if line.startswith('OPENAI_API_KEY='):
                print('OPENAI_API_KEY=[REDACTED]')
            else:
                print(line)
# Out:
# API key loaded successfully. First 5 characters: sk-pr
# Current working directory: /Users/lasyaedunuri/Documents/ApplOfLLMs/t-c
# Parent directory (where .env should be): /Users/lasyaedunuri/Documents/ApplOfLLMs
# .env file path: /Users/lasyaedunuri/Documents/ApplOfLLMs/.env
# .env file exists: False

# %%
import os
import sys
from dotenv import load_dotenv

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..'))) # Add the parent directory to the path since we work with notebooks
from helper_functions import *
from evaluate_rag import *

# Check if the API key is loaded correctly
api_key = os.getenv('OPENAI_API_KEY')
if api_key:
    print("API key loaded successfully")
    print(f"API key: {api_key[:5]}...{api_key[-5:]}")  # Print first and last 5 characters
else:
    print("Failed to load API key")

# Load environment variables from a .env file
load_dotenv()

# Set the OpenAI API key environment variable
os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY')
# Out:
# /var/folders/32/cnjh1pk53pv44d1ht_32rzcc0000gn/T/ipykernel_47273/1778645082.py:6: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   from helper_functions import *
# API key loaded successfully
# API key: sk-pr...EIBQA
# /Users/lasyaedunuri/Documents/ApplOfLLMs/t-c/venv/lib/python3.11/site-packages/deepeval/__init__.py:53: UserWarning: You are using deepeval version 1.5.3, however version 1.5.5 is available. You should consider upgrading via the "pip install --upgrade deepeval" command.
#   warnings.warn(

# %%
folders = ["src/cars", "src/E-commerce", "src/food", "src/electronics"]

# %%
import os
from langchain.vectorstores import FAISS
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter

# def encode_documents(folders, chunk_size=1000, chunk_overlap=200):
#     """
#     Encodes all text files from multiple folders into a FAISS vector store using OpenAI embeddings.

#     Args:
#         folders: A list of paths to directories containing text files.
#         chunk_size: The desired size of each text chunk.
#         chunk_overlap: The amount of overlap between consecutive chunks.

#     Returns:
#         A FAISS vector store containing the encoded content of the files.
#     """
#     # Initialize text splitter and embeddings
#     text_splitter = RecursiveCharacterTextSplitter(
#         chunk_size=chunk_size, chunk_overlap=chunk_overlap, length_function=len
#     )
#     embeddings = OpenAIEmbeddings()

#     # Initialize an empty list to store all text chunks
#     all_texts = []
#     metadata = []

#     # Iterate through each folder
#     for folder in folders:
#         for filename in os.listdir(folder):
#             if filename.endswith('.txt'):
#                 file_path = os.path.join(folder, filename)
                
#                 # Load text document
#                 with open(file_path, 'r', encoding='utf-8') as file:
#                     text = file.read()
                
#                 # Split text into chunks
#                 texts = text_splitter.split_text(text)
#                 all_texts.extend(texts)

#                 # Add metadata for each chunk
#                 metadata.extend([{"file_name": filename, "folder": folder}] * len(texts))
    
#     # Create vector store from all texts and their metadata
#     vectorstore = FAISS.from_texts(all_texts, embeddings, metadatas=metadata)
    
#     return vectorstore

def encode_documents(folders, chunk_size=1000, chunk_overlap=200):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size, chunk_overlap=chunk_overlap, length_function=len
    )
    embeddings = OpenAIEmbeddings()
    all_texts = []
    metadata = []

    for folder in folders:
        for filename in os.listdir(folder):
            if filename.endswith(".txt"):
                file_path = os.path.join(folder, filename)
                with open(file_path, "r", encoding="utf-8") as file:
                    text = file.read()
                texts = text_splitter.split_text(text)
                all_texts.extend(texts)
                metadata.extend([{"file_name": filename, "folder": folder}] * len(texts))
    
    vectorstore = FAISS.from_texts(all_texts, embeddings, metadatas=metadata)
    return vectorstore

# %%
vectorstore = encode_documents(folders)
print("FAISS vector store created successfully!")
# Out:
# /var/folders/32/cnjh1pk53pv44d1ht_32rzcc0000gn/T/ipykernel_47273/3158976551.py:54: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embeddings = OpenAIEmbeddings()
# FAISS vector store created successfully!

# %%
chunks_query_retriever = vectorstore.as_retriever(search_kwargs={"k": 2})

# %%
test_query = "Does METTLER TOLEDO's waive any provision?"
context = retrieve_context_per_question(test_query, chunks_query_retriever)
show_context(context)
# Out:
# /Users/lasyaedunuri/Documents/ApplOfLLMs/t-c/helper_functions.py:145: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   docs = chunks_query_retriever.get_relevant_documents(question)
# Context 1:
# Warranties; Disclaimers
#
#
# Context 2:
# (c) Class Action Waiver

# %%
evaluate_rag(chunks_query_retriever)
# Out:
# Answering the question from the retrieved context...
# Answering the question from the retrieved context...
# Answering the question from the retrieved context...
# Answering the question from the retrieved context...
# Answering the question from the retrieved context...
# Answering the question from the retrieved context...
# Answering the question from the retrieved context...
# Answering the question from the retrieved context...
# Answering the question from the retrieved context...
# Answering the question from the retrieved context...
# ✨ You're running DeepEval's latest Correctness (GEval) Metric! (using gpt-4o, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Faithfulness Metric! (using gpt-4, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Contextual Relevancy Metric! (using gpt-4, strict=False, async_mode=True)...
# Event loop is already running. Applying nest_asyncio patch to allow async execution...
# Evaluating 10 test case(s) in parallel: |          |  0% (0/10) [Time Taken: 00:00, ?test case/s]ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 4 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 4 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 4 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 4 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 4 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 4 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 4 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 4 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 4 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 4 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 4 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 5 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 4 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 5 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 5 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 5 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 5 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 5 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 4 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 5 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 4 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 4 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 4 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 6 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 5 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 6 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 6 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 6 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 5 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 6 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 5 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 5 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 5 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 6 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 4 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 7 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 7 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 6 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 4 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 7 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 7 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 4 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 6 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 6 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 5 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 6 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 7 time(s)...
# Evaluating 10 test case(s) in parallel: |█         | 10% (1/10) [Time Taken: 01:40, 100.04s/test case]ERROR:root:OpenAI rate limit exceeded. Retrying: 5 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 4 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 8 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 7 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 7 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 5 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 6 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 7 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 1 time(s)...
# Evaluating 10 test case(s) in parallel: |██        | 20% (2/10) [Time Taken: 01:59, 52.52s/test case] ERROR:root:OpenAI rate limit exceeded. Retrying: 6 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 5 time(s)...
# Evaluating 10 test case(s) in parallel: |███       | 30% (3/10) [Time Taken: 02:05, 31.40s/test case]ERROR:root:OpenAI rate limit exceeded. Retrying: 8 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 6 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 2 time(s)...
# Evaluating 10 test case(s) in parallel: |█████     | 50% (5/10) [Time Taken: 02:14, 15.08s/test case]ERROR:root:OpenAI rate limit exceeded. Retrying: 3 time(s)...
# ERROR:root:OpenAI rate limit exceeded. Retrying: 7 time(s)...
# Evaluating 10 test case(s) in parallel: |██████    | 60% (6/10) [Time Taken: 02:20, 11.84s/test case]ERROR:root:OpenAI rate limit exceeded. Retrying: 6 time(s)...
# Evaluating 10 test case(s) in parallel: |████████  | 80% (8/10) [Time Taken: 02:34,  9.46s/test case]ERROR:root:OpenAI rate limit exceeded. Retrying: 4 time(s)...
# Evaluating 10 test case(s) in parallel: |██████████|100% (10/10) [Time Taken: 02:55, 17.53s/test case]
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Correctness (GEval) (score: 0.2627560891579086, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The actual output is not factually correct; it does not directly answer the question of whether METTLER TOLEDO waives any provision., error: None)
#   - ✅ Faithfulness (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-4, reason: None, error: None)
#   - ❌ Contextual Relevancy (score: 0.5, threshold: 1.0, strict: False, evaluation model: gpt-4, reason: The score is 0.50 because although the 'Class Action Waiver' statement does provide some relevance to the input, the 'Warranties; Disclaimers' statement does not contribute any meaningful information about METTLER TOLEDO's waiving any provision., error: None)
#
# For test case:
#
#   - input: Does METTLER TOLEDO's waive any provision?
#   - actual output: The context provided does not specify whether METTLER TOLEDO waives any provision related to warranties, disclaimers, or class action waivers. More detailed information from the actual terms and conditions or legal documents would be needed to determine if any provisions are waived.
#   - expected output: No, METTLER TOLEDO does not waive any provision.
#   - context: None
#   - retrieval context: ['Warranties; Disclaimers', '(c) Class Action Waiver']
#
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Correctness (GEval) (score: 0.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The actual output discusses McDonald's instead of METTLER TOLEDO, failing to address the expected output., error: None)
#   - ✅ Faithfulness (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-4, reason: None, error: None)
#   - ❌ Contextual Relevancy (score: 0.0, threshold: 1.0, strict: False, evaluation model: gpt-4, reason: The score is 0.00 because the retrieval context is entirely irrelevant to the input. The context discusses 'McDonald's products and services', rules for using online services, and the 'Geographical Scope of the DD/BR Online Services'. None of these topics are related to whether METTLER TOLEDO provides products and services in all countries., error: None)
#
# For test case:
#
#   - input: Does METTLER TOLEDO provide products and services in all countries?
#   - actual output: The context provided is about McDonald's online services, not METTLER TOLEDO. Therefore, the context does not provide information about METTLER TOLEDO's availability of products and services in all countries.
#   - expected output: METTLER TOLEDO is a global company that provides precision instruments and services for laboratories and manufacturing. They have operations in many countries around the world and serve a wide range of industries. While they have a significant global presence, it is always best to check their official website or contact them directly to confirm if they provide products and services in a specific country.
#   - context: None
#   - retrieval context: ["1. About the online services.\nAvailability of products and services. \nMcDonald's products and services are available in many parts of the world. However, the online services may describe products and services that are not available worldwide.\n\nObey the rules of the road. \nWhenever you use the online services, you must obey the rules of the road and all applicable rules and regulations. You must not use the online services while driving or while behind the wheel or controls of a vehicle that is moving or not in “park”. In the interest of safety at all times, you should only use the online services when it is lawful and safe to do so.", 'Geographical Scope of the DD/BR Online Services']
#
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Correctness (GEval) (score: 0.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The actual output incorrectly states that third-party delivery services are not covered by the Chick-fil-A One rewards program, contradicting the expected output which confirms coverage., error: None)
#   - ✅ Faithfulness (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-4, reason: None, error: None)
#   - ✅ Contextual Relevancy (score: 1.0, threshold: 1.0, strict: False, evaluation model: gpt-4, reason: The score is 1.00 because all statements in the retrieval context directly answer the input question, clarifying that third-party delivery services are not covered by the Chick-fil-A One rewards program., error: None)
#
# For test case:
#
#   - input: Are third-party delivery services covered by the Chick-fil-A One rewards program?
#   - actual output: No, third-party delivery services are not covered by the Chick-fil-A One rewards program. Orders placed through third-party delivery platforms are not qualifying purchases and are not eligible to receive Chick-fil-A One® points or redeem rewards.
#   - expected output: Yes, Chick-fil-A One rewards program covers third-party delivery services such as DoorDash and Uber Eats. Customers can earn points and redeem rewards when using these delivery services to order Chick-fil-A.
#   - context: None
#   - retrieval context: ['provider at the time of the order.  For clarification, delivery orders initiated on third-party food delivery platforms are not qualifying purchases and are not eligible to receive Chick-fil-A One® points or redeem rewards.', 'Third-Party Delivery Services. Delivery may also be available through select third-party delivery services identified on the Chick-fil-A website or in the App for qualifying orders placed at participating Chick-fil-A restaurant locations. When ordering through a third-party delivery service, you understand and agree that you are placing the order with that third-party service provider and not Chick fil A or a Chick-fil-A restaurant Operator. The delivery services are provided by the third party, and Chick-fil-A and the participating Chick-fil-A restaurant Operators have no responsibility or liability for the acts or omissions of the third-party delivery service provider. All orders placed through a third-party delivery service are subject to any terms and conditions provided by that service provider at the time of the order.  For clarification, delivery orders initiated on third-party food delivery platforms are not qualifying purchases and are not eligible to receive Chick-fil-A One®']
#
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Correctness (GEval) (score: 0.10640773549212104, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The actual output fails to mention OpenAI's restrictions on commercial use of AI-generated content, such as prohibiting illegal or harmful use and marking content as AI-generated., error: None)
#   - ✅ Faithfulness (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-4, reason: None, error: None)
#   - ❌ Contextual Relevancy (score: 0.5, threshold: 1.0, strict: False, evaluation model: gpt-4, reason: The score is 0.50 because while the retrieval context does mention 'acceptable uses and restrictions for the online services', it does not specifically deal with OpenAI's restrictions on using generated output for commercial purposes as indicated by the irrelevancy reasons., error: None)
#
# For test case:
#
#   - input: What are OpenAI's restrictions on using generated output for commercial purposes?
#   - actual output: The context provided does not mention OpenAI's restrictions on using generated output for commercial purposes. It discusses user-generated content and the waiver of rights, but does not specify OpenAI's policies on commercial use of generated output.
#   - expected output: OpenAI's restrictions on using generated output for commercial purposes include prohibiting the use of their models for generating content that is illegal, harmful, or fraudulent. Additionally, they require users to clearly mark content produced by AI models to make it clear that the content was generated by an AI system.
#   - context: None
#   - retrieval context: ['By providing User-Generated Content, you agree not to claim that any use of that User-Generated Content by us, any Site user, or any third party infringes or violates your or any person’s intellectual property rights (including, without limitation, copyright), rights of privacy, rights of publicity, or other rights, and you waive any and all moral rights in or to the User-Generated Content.\n\nUser-Generated Content may be subject to additional terms as posted on the Site from time to time, such as those applicable to a particular contest or promotion. To the extent any provision of this section conflicts with any provision of those additional terms with respect to User-Generated Content, the applicable additional terms will control.', '8. Acceptable uses and restrictions for the online services.\nAcceptable uses and other restrictions. \nWith respect to the online services (which includes content) or any portion thereof, you may not, and may not allow third parties, to:']
#
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Correctness (GEval) (score: 0.14035307128606417, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: Actual output lacks details on specific information like phone number and location data disclosed by wireless operators to Bank of America or Zelle®, only mentioning general sharing with service providers., error: None)
#   - ✅ Faithfulness (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-4, reason: None, error: None)
#   - ❌ Contextual Relevancy (score: 0.25, threshold: 1.0, strict: False, evaluation model: gpt-4, reason: The score is 0.25 because while one statement does mention sharing information with wireless carriers, it does not specifically address what information a wireless operator might disclose to Bank of America or Zelle®. The irrelevant context mostly discusses topics such as user responsibility for charges, availability and changes to wireless service, and terms based on device type., error: None)
#
# For test case:
#
#   - input: What information might my wireless operator disclose to Bank of America or Zelle® when I use their service?
#   - actual output: The context does not specify what information your wireless operator might disclose to Bank of America or Zelle® when you use their service. It only mentions that information may be shared with service providers and partners involved in e-commerce and retail fulfillment activities, and that you are responsible for charges related to mobile device usage.
#   - expected output: When you use a wireless operator's service to make transactions through Bank of America or Zelle®, the wireless operator may disclose information such as your phone number, location data, transaction details, and payment history to facilitate the transaction process. Additionally, they may also share information related to your account status, device information, and network data in order to ensure the security and functionality of the transaction.
#   - context: None
#   - retrieval context: ['We may share this information with service providers and partners who are involved in our e-commerce and retail fulfillment activities, such as data hosting companies; payment processors; financial institutions; shipping companies; and wireless carriers (if carrier services are ordered or activated via our site).', 'You agree that you are solely responsible for all message and data charges that apply to use of your mobile device to access the DD/BR Online Services. All such charges are billed by and payable to your mobile service provider. Please contact your participating mobile service provider for pricing plans, participation status and details.\nYou understand that wireless service may not be available in all areas at all times and may be affected by product, software, coverage or service changes made by your service provider or otherwise.\nAdditional terms and conditions may apply to your use of our mobile applications based on the type of mobile device that you use.']
#
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Correctness (GEval) (score: 0.05146242726737984, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The actual output does not mention specific personal information accessed by Bank of America as stated in the expected output, and instead refers to unrelated practices by Apple., error: None)
#   - ✅ Faithfulness (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-4, reason: None, error: None)
#   - ❌ Contextual Relevancy (score: 0.2, threshold: 1.0, strict: False, evaluation model: gpt-4, reason: The score is 0.20 because the majority of the content is about 'Apple' collecting data for various purposes, not 'Bank of America' using wireless account information to prevent fraud. However, one statement does mention actions to prevent unauthorized access and keep accounts secure, providing some relevance to the input., error: None)
#
# For test case:
#
#   - input: What personal information does Bank of America access from my wireless account to prevent fraud?
#   - actual output: The context does not provide specific information about what personal information Bank of America accesses from your wireless account to prevent fraud. It only mentions general practices related to business security, risk control, and fraud prevention by Apple, such as collecting data like name, purchase, and payment information for processing transactions and communicating with users.
#   - expected output: Bank of America may access certain personal information from your wireless account to prevent fraud, such as your phone number, device information, location data, and call and text records. This information helps the bank verify your identity and detect any suspicious activity on your account.
#   - context: None
#   - retrieval context: ['(d) Business security and risk control\nTo ensure the security of our service systems, prevent unauthorized access or cyber-attacks, improve our loss prevention and anti-fraud programs, identify risks to your service account and keep your account secure.\n(e) Personalized services and marketing information', 'Process Your Transactions. To process transactions, Apple must collect data such as your name, purchase, and payment information.\n\nCommunicate with You. To respond to communications, reach out to you about your transactions or account, market our products and services, provide other relevant information, or request information or feedback. From time to time, we may use your personal data to send important notices, such as communications about purchases and changes to our terms, conditions, and policies. Because this information is important to your interaction with Apple, you may not opt out of receiving these important notices.\n\nSecurity and Fraud Prevention. To protect individuals, employees, and Apple and for loss prevention and to prevent fraud, including to protect individuals, employees, and Apple for the benefit of all our users, and prescreening or scanning uploaded content for potentially illegal content, including child sexual exploitation material.']
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Correctness (GEval) (score: 0.9984093610557924, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The actual output correctly states that Chick-fil-A's Terms and Conditions do not allow class action lawsuits and provides additional details that align with the expected output., error: None)
#   - ✅ Faithfulness (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-4, reason: None, error: None)
#   - ❌ Contextual Relevancy (score: 0.25, threshold: 1.0, strict: False, evaluation model: gpt-4, reason: The score is 0.25 because while the retrieval context does contain some relevant information on class action lawsuits in Chick-fil-A's Terms and Conditions, many of the statements in the retrieval context are irrelevant as they do not address the specific question about 'class action lawsuits'., error: None)
#
# For test case:
#
#   - input: Does Chick-fil-A's Terms and Conditions allow class action lawsuits?
#   - actual output: No, Chick-fil-A's Terms and Conditions do not allow class action lawsuits. By accepting the terms, you agree to resolve disputes through binding arbitration or small claims dispute procedures and waive your rights to participate in a class action suit.
#   - expected output: Chick-fil-A's Terms and Conditions do not allow class action lawsuits.
#   - context: None
#   - retrieval context: ['If Chick-fil-A takes legal action against you as a result of your violation of these Terms and Conditions of Use, we will be entitled to recover from you, and you agree to pay, all reasonable attorneys’ fees and costs of such action, in addition to any other relief granted to Chick-fil-A. You agree that Chick-fil-A will not be liable to you or to any third party for termination of your access to the CFA Online Services as a result of any violation of these Terms and Conditions of Use.\n\nXXIII.  Entire Agreement, Claims Limitations, and Severability', 'Chick-fil-A, Inc. Terms and Conditions of Use\n\nLast Updated: June 19, 2023\n\nPLEASE READ THESE TERMS AND CONDITIONS OF USE CAREFULLY BEFORE DOWNLOADING, ACCESSING, OR USING ANY CFA ONLINE SERVICES (AS DEFINED BELOW).\n\nBY ACCEPTING THESE TERMS AND CONDITIONS OF USE, AS DETAILED IN SECTION XX BELOW, YOU AGREE TO RESOLVE ANY DISPUTE IN ANY WAY ARISING OUT OF OR RELATING TO THESE TERMS AND CONDITIONS OF USE, OUR PRIVACY POLICY, DATA SECURITY, OR DATA PRIVACY THROUGH BINDING ARBITRATION OR SMALL CLAIMS DISPUTE PROCEDURES, UNLESS OTHERWISE PROVIDED BELOW, AND YOU AGREE TO WAIVE YOUR RIGHTS TO PARTICIPATE IN A CLASS ACTION SUIT. \n\nBY ACCEPTING THESE TERMS AND CONDITIONS OF USE, YOU ALSO AGREE TO OUR PRIVACY POLICY, LOCATED AT https://www.chick-fil-a.com/legal, WHICH IS INCORPORATED INTO THESE TERMS AND CONDITIONS OF USE AND MAY BE UPDATED FROM TIME TO TIME.\n\nTable of Contents']
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Correctness (GEval) (score: 0.7271496331608515, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The actual output provides specific instructions for a particular contest, aligning with the expected output's emphasis on following instructions and reading rules. However, it lacks general guidance for other contests as mentioned in the expected output., error: None)
#   - ✅ Faithfulness (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-4, reason: None, error: None)
#   - ✅ Contextual Relevancy (score: 1.0, threshold: 1.0, strict: False, evaluation model: gpt-4, reason: The score is 1.00 because all of the provided statements in the retrieval context are directly relevant to the input query about submitting a contest entry for BurgerKing, including detailed instructions on how to create and submit a contest entry, the rules of the contest, and the contest timeline., error: None)
#
# For test case:
#
#   - input: how to submit a contest entry for BurgerKing?
#   - actual output: To submit a contest entry for Burger King, visit BK.com/mdw during the Contest Submission Period, accept the Contest Official Rules, and follow the instructions to create and submit your entry. First, select a patty for your Whopper Idea, then add 3 to 8 edible toppings, ensuring each topping name is in English and within 25 characters. You can submit up to three entries between February 5, 2024, at 10:00 a.m. ET and March 17, 2024, at 11:59 p.m. ET.
#   - expected output: To submit a contest entry for Burger King, you typically need to visit their official website or social media pages to find information about the contest you wish to enter. Many contests may require you to follow specific instructions such as sharing a post, creating content, or filling out a form. Be sure to read the rules and guidelines for the contest carefully to ensure you meet all the requirements for entry. If you have any specific contest details in mind, I can provide more tailored guidance.
#   - context: None
#   - retrieval context: ["Sponsor's computer is the official time-keeping device for the Contest.\n5. How To Submit A Contest Entry: During the Contest Submission Period, visit BK.com/mdw (“Site”), accept the Contest Official Rules http://www.heya.toyota.comand follow the instructions to create and submit your Contest Entry. \nStep 1: Entrant is presented with a bun and first selects either a 100% Flame Grilled Beef patty or an Impossible™ patty for their Whopper Idea. This selection is not part of the Entrant’s Contest Entry and will not impact the Sponsor’s assessment of the Whopper Idea for purposes of this Contest\nStep 2: Entrant must add at least three (3), but no more than eight (8) “Toppings” (see Toppings Guidelines section below) in order to create a Contest Entry.\n1. Toppings must be edible food items2. Toppings must be written in English and there is a 25 character limitation on the Topping Name3. The Site will not allow Entrants to include:", '• Contest Submission Period: Entrants may submit up to three (3) Contest Entries from February 5, 2024 at 10:00 a.m. ET through March 17, 2024 at 11:59 p.m. ET.• Judging Of Contest Entries & Selection Of 3 MDW Contenders: From March 18, 2024 through mid-April 2024, Sponsor will judge Contest Entries to select three MDW Contenders, and if necessary, will conduct a random drawing to select the Finalist to represent the selected MDW Contender. In May 2024 (dates determined by Sponsor), Finalists will be invited to Burger King headquarters to help finalize a restaurant-ready version of their MDW Contender based on their respective Contest Entry to produce a LTO Whopper® sandwich that will be offered in restaurant.• Public Voting Of The MDW Contenders (LTO Whoppers): Sponsor will offer online public voting of the three LTO Whopper® sandwiches, during the same period that they are available at participating Burger King restaurants in November 2024. Members of the public who have a BK® Royal']
#
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Correctness (GEval) (score: 0.24995963520854997, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The actual output lacks information on redemption limitations at participating locations, missing key factual correctness about location-specific participation., error: None)
#   - ✅ Faithfulness (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-4, reason: None, error: None)
#   - ❌ Contextual Relevancy (score: 0.5555555555555556, threshold: 1.0, strict: False, evaluation model: gpt-4, reason: The score is 0.56 because while the relevant statements provide information on how to redeem Chick-fil-A One points, they do not specifically address whether points can be redeemed at all locations. The irrelevant statements discuss points subtraction and restoration, misuse of offers, verification codes, and limitations on rewards, none of which directly answer the question about location-specific redemption., error: None)
#
# For test case:
#
#   - input: Can I redeem my Chick-fil-A One points at all locations?
#   - actual output: The context does not specify whether Chick-fil-A One points can be redeemed at all locations. It only provides information on how to redeem points and the conditions under which points can be restored or accounts terminated.
#   - expected output: No, Chick-fil-A One points can only be redeemed at participating Chick-fil-A restaurants. Not all locations may participate in the rewards program, so it's best to check with your local Chick-fil-A to confirm if they accept Chick-fil-A One points.
#   - context: None
#   - retrieval context: ["Points will be subtracted from the Member's Chick-fil-A One account immediately when a Reward is requested based on the total Points for the requested Reward. Points will be restored to a Member's Chick-fil-A One account only in the event Chick fil A determines, in its sole and absolute discretion, that the Reward requested by that Member is unavailable or cannot be delivered. Chick-fil-A reserves the right to limit the redemption of specific Rewards and limit the number of Rewards available at any particular Membership Tier.\n\nAttempts to redeem single use offers and verification codes for Rewards multiple times or through multiple users constitutes fraud and may result in the termination or suspension of your Chick-fil-A One account.", 'Redeeming Rewards. To redeem Points for available Chick-fil-A rewards (“Rewards”), you must access the Rewards section on the App or online at www.chick-fil-a.com/MyProfile/AddRewards to view Rewards available for redemption, and then select to redeem an available Reward. You must have at least enough available Points in your Chick-fil-A One account (“Available Points”) for the Reward you wish to redeem. Members must accrue a minimum of two hundred (200) Available Points before the first redemption for any Reward. In any single transaction, only one Chick fil A One account may be used to redeem Points for Rewards. Points accrued by a Member in any purchase or transaction may only be redeemed for Rewards in a separate, subsequent purchase or transaction. Rewards can only be redeemed through the App or online at www.chick-fil-a.com/MyProfile/AddRewards or https://order.chick-fil-a.com while logged into your Chick-fil-A One Account. Rewards cannot be redeemed through any third-party']
#
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Correctness (GEval) (score: 0.2356071160427013, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: Actual output mentions rewards but focuses on offer distribution and usage, lacking mention of gift cards and points accumulation present in expected output., error: None)
#   - ✅ Faithfulness (score: 0.9090909090909091, threshold: 0.7, strict: False, evaluation model: gpt-4, reason: None, error: None)
#   - ✅ Contextual Relevancy (score: 1.0, threshold: 1.0, strict: False, evaluation model: gpt-4, reason: The score is 1.00 because the retrieval context provides a comprehensive explanation of Chick-fil-A's policy on gift offers and digital rewards, covering aspects such as how offers are sent, how they are accessed, redemption period, and restrictions on usage., error: None)
#
# For test case:
#
#   - input: What is Chick-fil-A's policy on gift offers and digital rewards?
#   - actual output: Chick-fil-A and participating restaurants may send offers via the App or email to Members, or distribute physical offer cards to customers. These offers, called 'treats' and 'rewards,' require accessing a Chick-fil-A One account to obtain a QR Code for redemption. Members can transfer up to three physical offers per week, with a maximum of ten per month, to their account. Offers are single-use, redeemable only at participating locations, and may not be accepted at Chick-fil-A Express or licensed locations. Offers are void if altered or sold, and are subject to serving times and availability.
#   - expected output: Chick-fil-A offers gift cards that can be purchased online or at their restaurants. They also have a rewards program called Chick-fil-A One that allows customers to earn points for their purchases and redeem them for rewards. Customers can sign up for the Chick-fil-A One program through their app or online.
#   - context: None
#   - retrieval context: ['Guest Offers; Digital Offer Cards. Chick-fil-A and participating Chick-fil-A restaurants, in their sole and absolute discretion, may periodically send offers via the App or via email to Members, or distribute offers to customers (whether or not they are Members) through physical offer cards. These offers are referred to as ‘treats’ and ‘rewards’ but may appear with different descriptions from time to time (collectively, “Guest Offers”). In order to receive digital Guest Offers sent to Members via their Chick-fil-A One account, eligible individuals must access their valid Chick-fil-A One account via www.chick-fil-a.com/one or via the App to obtain the QR Code for the Guest Offer. To transfer a Guest Offer from a physical offer card to a Chick-fil-A One account, open the Chick-fil-A App and scan the Guest Offer’s QR Code. A Member may transfer no more than three Guest Offers per week, up to a maximum of ten Guest Offers per month, from a physical offer card to their Chick-fil-A One', 'Redemption period for each offer begins and ends as indicated.\nOffers are single use only, unless otherwise stated. Once a digital offer code has been redeemed, it will no longer be available.  \nOffers may only be redeemed at participating Chick-fil-A restaurant(s). Offers may not be accepted at some Chick-fil-A restaurants, including Chick-fil-A Express™ and Chick-fil-A licensed locations such as airports, college campuses, office complexes and hospitals.\nServing times apply and some food and/or beverage items may not be available at all times or locations. For example, offers for breakfast items may only be redeemed prior to 10 AM or 10:30 AM local time, depending on how late the applicable participating restaurant serves breakfast.\nOffers are not transferable.\nOffers are void where restricted, prohibited or taxed, or if reproduced, altered, purchased, distributed, auctioned, or sold.']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Correctness (GEval): 20.00% pass rate
# Faithfulness: 100.00% pass rate
# Contextual Relevancy: 30.00% pass rate
#
# ======================================================================
# ✓ Tests finished 🎉! Run 'deepeval login' to save and analyze evaluation results on Confident AI.
# ‼️  Friendly reminder 😇: You can also run evaluations with ALL of deepeval's metrics directly on Confident AI
# instead.
